# %%
# Importing required packages 
import matplotlib.pyplot as plt # version 1.25.2
import numpy as np # version 1.25.2

# Data extracted from the images

# Rounds
rounds = [1, 2, 3, 4, 5]

# Client Metrics - Accuracy
client_accuracies = {
    'client1': [0.5167, 0.5017, 0.5013, 0.5110, 0.4945],
    'client2': [0.4927, 0.5110, 0.5038, 0.5017, 0.5092],
    'client3': [0.5095, 0.5088, 0.5120, 0.4983, 0.5060],
    'client4': [0.5132, 0.5120, 0.5055, 0.5120, 0.5160],
    'client5': [0.5167, 0.5128, 0.4980, 0.5123, 0.4965]
}

# Client Metrics - Loss
client_losses = {
    'client1': [0.8044, 0.8440, 0.8354, 0.8332, 0.8247],
    'client2': [0.8455, 0.8308, 0.8282, 0.8274, 0.8204],
    'client3': [0.8242, 0.8120, 0.8420, 0.8287, 0.8080],
    'client4': [0.8316, 0.8098, 0.8140, 0.8233, 0.8121],
    'client5': [0.8218, 0.8397, 0.8300, 0.8292, 0.8234]
}

# Global Model Metrics - Accuracy
global_accuracy = [0.5098, 0.5095, 0.5077, 0.5076, 0.5069]
global_val_accuracy = [0.4970, 0.4937, 0.4934, 0.4916, 0.4933]

# Global Model Metrics - Loss
global_loss = [0.8255, 0.8264, 0.8276, 0.8278, 0.8258]
global_val_loss = [0.8268, 0.8298, 0.8307, 0.8312, 0.8288]

# Define markers for each client
client_markers = {
    'client1': 'x',
    'client2': 's',
    'client3': 'o',
    'client4': 'd',
    'client5': '^'
}

# Plotting the results in a grid layout
fig, axs = plt.subplots(2, 2, figsize=(15, 10))

# Plot Client Accuracy
for client, accuracies in client_accuracies.items():
    axs[0, 0].plot(rounds, accuracies, marker=client_markers[client], color='black', label=client, linestyle='-')
axs[0, 0].set_title('Client Accuracy Over Rounds')
axs[0, 0].set_xlabel('Rounds')
axs[0, 0].set_ylabel('Accuracy')
axs[0, 0].set_xticks(rounds)  # Set x-axis ticks to whole numbers only
axs[0, 0].legend(loc='upper center', bbox_to_anchor=(0.5, 0.1), ncol=5)
axs[0, 0].grid(False)

# Plot Global Model Accuracy
axs[0, 1].plot(rounds, global_accuracy, marker='o', color='black', label='Global Accuracy', linestyle='-')
axs[0, 1].plot(rounds, global_val_accuracy, marker='x', color='black', label='Validation Accuracy', linestyle='--')
axs[0, 1].set_title('Global Model Accuracy Over Rounds')
axs[0, 1].set_xlabel('Rounds')
axs[0, 1].set_ylabel('Accuracy')
axs[0, 1].set_xticks(rounds)  # Set x-axis ticks to whole numbers only
axs[0, 1].legend(loc='upper right', bbox_to_anchor=(1.001, 1.015))
axs[0, 1].grid(False)

# Plot Client Loss
for client, losses in client_losses.items():
    axs[1, 0].plot(rounds, losses, marker=client_markers[client], color='black', label=client, linestyle='-')
axs[1, 0].set_title('Client Loss Over Rounds')
axs[1, 0].set_xlabel('Rounds')
axs[1, 0].set_ylabel('Loss')
axs[1, 0].set_xticks(rounds)  # Set x-axis ticks to whole numbers only
axs[1, 0].legend()
axs[1, 0].grid(False)

# Plot Global Model Loss
axs[1, 1].plot(rounds, global_loss, marker='o', color='black', label='Global Loss', linestyle='-')
axs[1, 1].plot(rounds, global_val_loss, marker='x', color='black', label='Validation Loss', linestyle='--')
axs[1, 1].set_title('Global Model Loss Over Rounds')
axs[1, 1].set_xlabel('Rounds')
axs[1, 1].set_ylabel('Loss')
axs[1, 1].set_xticks(rounds)  # Set x-axis ticks to whole numbers only
axs[1, 1].legend()
axs[1, 1].grid(False)

# Add a common title
fig.suptitle("Results Technological IID Training", fontsize=16)

# Adjust layout to make room for the main title
plt.tight_layout(rect=[0, 0.03, 1, 0.95])

# Show the plots
plt.show()

# %%
# Rounds
rounds = [1, 2, 3, 4, 5]

# Client Metrics - Accuracy
client_accuracies = {
    'client1': [0.5706, 0.5213, 0.5665, 0.5722, 0.5779],
    'client2': [0.8423, 0.8940, 0.8940, 0.8737, 0.7826],
    'client3': [0.5751, 0.5679, 0.5651, 0.5751, 0.5608],
    'client4': [0.2203, 0.8259, 0.8133, 0.2058, 0.8249],
    'client5': [0.6950, 0.6915, 0.8047, 0.7574, 0.7739]
}

# Client Metrics - Loss
client_losses = {
    'client1': [0.8448, 0.8276, 0.7953, 0.8053, 0.7945],
    'client2': [0.6105, 0.6041, 0.5858, 0.7782, 0.7422],
    'client3': [0.8046, 0.8083, 0.7879, 0.8265, 0.8255],
    'client4': [0.9146, 0.6460, 0.6883, 0.9907, 0.7134],
    'client5': [0.7808, 0.7890, 0.6865, 0.7507, 0.7205]
}

# Global Model Metrics - Accuracy
global_accuracy = [0.5807, 0.6404, 0.6698, 0.6516, 0.6621]
global_val_accuracy = [0.5719, 0.6347, 0.6637, 0.6456, 0.6561]

# Global Model Metrics - Loss
global_loss = [0.7911, 0.7630, 0.7449, 0.7663, 0.7649]
global_val_loss = [0.7938, 0.7665, 0.7490, 0.7690, 0.7668]

# Define markers for each client
client_markers = {
    'client1': 'x',
    'client2': 's',
    'client3': 'o',
    'client4': 'd',
    'client5': '^'
}

# Plotting the results in a grid layout
fig, axs = plt.subplots(2, 2, figsize=(15, 10))

# Plot Client Accuracy
for client, accuracies in client_accuracies.items():
    axs[0, 0].plot(rounds, accuracies, marker=client_markers[client], color='black', label=client, linestyle='-')
axs[0, 0].set_title('Client Accuracy Over Rounds')
axs[0, 0].set_xlabel('Rounds')
axs[0, 0].set_ylabel('Accuracy')
axs[0, 0].set_xticks(rounds)  # Set x-axis ticks to whole numbers only
axs[0, 0].legend()
axs[0, 0].grid(False)

# Plot Global Model Accuracy
axs[0, 1].plot(rounds, global_accuracy, marker='o', color='black', label='Global Accuracy', linestyle='-')
axs[0, 1].plot(rounds, global_val_accuracy, marker='x', color='black', label='Validation Accuracy', linestyle='--')
axs[0, 1].set_title('Global Model Accuracy Over Rounds')
axs[0, 1].set_xlabel('Rounds')
axs[0, 1].set_ylabel('Accuracy')
axs[0, 1].set_xticks(rounds)  # Set x-axis ticks to whole numbers only
axs[0, 1].legend()
axs[0, 1].grid(False)

# Plot Client Loss
for client, losses in client_losses.items():
    axs[1, 0].plot(rounds, losses, marker=client_markers[client], color='black', label=client, linestyle='-')
axs[1, 0].set_title('Client Loss Over Rounds')
axs[1, 0].set_xlabel('Rounds')
axs[1, 0].set_ylabel('Loss')
axs[1, 0].set_xticks(rounds)  # Set x-axis ticks to whole numbers only
axs[1, 0].legend()
axs[1, 0].grid(False)

# Plot Global Model Loss
axs[1, 1].plot(rounds, global_loss, marker='o', color='black', label='Global Loss', linestyle='-')
axs[1, 1].plot(rounds, global_val_loss, marker='x', color='black', label='Validation Loss', linestyle='--')
axs[1, 1].set_title('Global Model Loss Over Rounds')
axs[1, 1].set_xlabel('Rounds')
axs[1, 1].set_ylabel('Loss')
axs[1, 1].set_xticks(rounds)  # Set x-axis ticks to whole numbers only
axs[1, 1].legend()
axs[1, 1].grid(False)

# Add a common title
fig.suptitle("Results Technological Non-IID Training", fontsize=16)

# Adjust layout to make room for the main title
plt.tight_layout(rect=[0, 0.03, 1, 0.95])

# Show the plots
plt.show()

# %%
# Rounds
rounds = [1, 2, 3, 4, 5]

# Jittered Client Metrics - Accuracy
client_accuracies = {
    'client1': np.array([1.0000, 1.0000, 1.0000, 1.0000, 1.0000]) + 0.0001,
    'client2': np.array([1.0000, 1.0000, 1.0000, 1.0000, 1.0000]) - 0.0001,
    'client3': np.array([1.0000, 1.0000, 1.0000, 1.0000, 1.0000]) + 0.0002,
    'client4': np.array([1.0000, 1.0000, 1.0000, 1.0000, 1.0000]) - 0.0002,
    'client5': np.array([1.0000, 1.0000, 1.0000, 1.0000, 1.0000])
}


# Client Metrics - Loss
client_losses = {
    'client1': [0.0169, 0.0137, 0.0065, 0.0091, 0.0141],
    'client2': [0.0082, 0.0096, 0.0058, 0.0074, 0.0109],
    'client3': [0.0058, 0.0079, 0.0060, 0.0065, 0.0027],
    'client4': [0.0111, 0.0185, 0.0169, 0.0076, 0.0179],
    'client5': [0.0123, 0.0103, 0.0071, 0.0050, 0.0108]
}

# Jittered Global Model Metrics - Accuracy
global_accuracy = np.array([1.0000, 1.0000, 1.0000, 1.0000, 1.0000]) + 0.0001
global_val_accuracy = np.array([1.0000, 1.0000, 1.0000, 1.0000, 1.0000]) 


# Global Model Metrics - Loss
global_loss = [0.0109, 0.0114, 0.0104, 0.0100, 0.0103]
global_val_loss = [0.0020, 0.0021, 0.0019, 0.0019, 0.0020]

# Define markers for each client
client_markers = {
    'client1': 'x',
    'client2': 's',
    'client3': 'o',
    'client4': 'd',
    'client5': '^'
}

# Plotting the results in a grid layout
fig, axs = plt.subplots(2, 2, figsize=(15, 10))

# Plot Client Accuracy
for client, accuracies in client_accuracies.items():
    axs[0, 0].plot(rounds, accuracies, marker=client_markers[client], color='black', label=client, linestyle='-')
axs[0, 0].set_title('Client Accuracy Over Rounds')
axs[0, 0].set_xlabel('Rounds')
axs[0, 0].set_ylabel('Accuracy')
axs[0, 0].set_xticks(rounds)  # Set x-axis ticks to whole numbers only
axs[0, 0].set_ylim(0.999, 1.001)
axs[0, 0].legend()
axs[0, 0].grid(False)

# Plot Global Model Accuracy
axs[0, 1].plot(rounds, global_accuracy, marker='o', color='black', label='Global Accuracy', linestyle='-')
axs[0, 1].plot(rounds, global_val_accuracy, marker='x', color='black', label='Validation Accuracy', linestyle='--')
axs[0, 1].set_title('Global Model Accuracy Over Rounds')
axs[0, 1].set_xlabel('Rounds')
axs[0, 1].set_ylabel('Accuracy')
axs[0, 1].set_xticks(rounds)  # Set x-axis ticks to whole numbers only
axs[0, 1].set_ylim(0.999, 1.001)
axs[0, 1].legend()
axs[0, 1].grid(False)

# Plot Client Loss
for client, losses in client_losses.items():
    axs[1, 0].plot(rounds, losses, marker=client_markers[client], color='black', label=client, linestyle='-')
axs[1, 0].set_title('Client Loss Over Rounds')
axs[1, 0].set_xlabel('Rounds')
axs[1, 0].set_ylabel('Loss')
axs[1, 0].set_xticks(rounds)  # Set x-axis ticks to whole numbers only
axs[1, 0].set_ylim(-0.02, 0.04)
axs[1, 0].legend()
axs[1, 0].grid(False)

# Plot Global Model Loss
axs[1, 1].plot(rounds, global_loss, marker='o', color='black', label='Global Loss', linestyle='-')
axs[1, 1].plot(rounds, global_val_loss, marker='x', color='black', label='Validation Loss', linestyle='--')
axs[1, 1].set_title('Global Model Loss Over Rounds')
axs[1, 1].set_xlabel('Rounds')
axs[1, 1].set_ylabel('Loss')
axs[1, 1].set_xticks(rounds)  # Set x-axis ticks to whole numbers only
axs[1, 1].set_ylim(-0.02, 0.04)
axs[1, 1].legend()
axs[1, 1].grid(False)

# Add a common title
fig.suptitle("Results Medical IID Training", fontsize=16)

# Adjust layout to make room for the main title
plt.tight_layout(rect=[0, 0.03, 1, 0.95])

# Show the plots
plt.show()

# %%
# Rounds
rounds = [1, 2, 3, 4, 5]

# Client Metrics - Accuracy
client_accuracies = {
    'client1': np.array([0.9062, 0.9231, 0.9103, 0.8974, 0.8718]),
    'client2': np.array([0.6957, 0.7391, 0.7188, 0.7391, 0.8125]),
    'client3': np.array([1.0000, 1.0000, 1.0000, 1.0000, 1.0000]),
    'client4': np.array([0.7826, 0.7391, 0.5652, 0.6087, 0.5938]),
    'client5': np.array([1.0000, 1.0000, 1.0000, 1.0000, 1.0000]) - 0.03 # jittering client 5 for better visibility
}

# Client Metrics - Loss
client_losses = {
    'client1': [0.1458, 0.1533, 0.1652, 0.1884, 0.1740],
    'client2': [0.3353, 0.4212, 0.3893, 0.3346, 0.3261],
    'client3': [0.0513, 0.0246, 0.0511, 0.1190, 0.1765],
    'client4': [0.3010, 0.2690, 0.4610, 0.4335, 0.4505],
    'client5': [0.0497, 0.1182, 0.0192, 0.0512, 0.0233]
}

# Global Model Metrics - Accuracy
global_accuracy = [0.8769, 0.8786, 0.8653, 0.8613, 0.8601]
global_val_accuracy = [0.7937, 0.7636, 0.7486, 0.7470, 0.7400]

# Global Model Metrics - Loss
global_loss = [0.1766, 0.1869, 0.1970, 0.2041, 0.2093]
global_val_loss = [0.2832, 0.3236, 0.3428, 0.3404, 0.3424]

# Define markers for each client
client_markers = {
    'client1': 'x',
    'client2': 's',
    'client3': 'o',
    'client4': 'd',
    'client5': '^'
}

# Plotting the results in a grid layout
fig, axs = plt.subplots(2, 2, figsize=(15, 10))

# Plot Client Accuracy
for client, accuracies in client_accuracies.items():
    axs[0, 0].plot(rounds, accuracies, marker=client_markers[client], color='black', label=client, linestyle='-')
axs[0, 0].set_title('Client Accuracy Over Rounds')
axs[0, 0].set_xlabel('Rounds')
axs[0, 0].set_ylabel('Accuracy')
axs[0, 0].set_xticks(rounds)  # Set x-axis ticks to whole numbers only
axs[0, 0].set_ylim(0.4, 1.1)
axs[0, 0].legend()
axs[0, 0].grid(False)

# Plot Global Model Accuracy
axs[0, 1].plot(rounds, global_accuracy, marker='o', color='black', label='Global Accuracy', linestyle='-')
axs[0, 1].plot(rounds, global_val_accuracy, marker='x', color='black', label='Validation Accuracy', linestyle='--')
axs[0, 1].set_title('Global Model Accuracy Over Rounds')
axs[0, 1].set_xlabel('Rounds')
axs[0, 1].set_ylabel('Accuracy')
axs[0, 1].set_xticks(rounds)  # Set x-axis ticks to whole numbers only
axs[0, 1].set_ylim(0.4, 1.1)
axs[0, 1].legend()
axs[0, 1].grid(False)

# Plot Client Loss
for client, losses in client_losses.items():
    axs[1, 0].plot(rounds, losses, marker=client_markers[client], color='black', label=client, linestyle='-')
axs[1, 0].set_title('Client Loss Over Rounds')
axs[1, 0].set_xlabel('Rounds')
axs[1, 0].set_ylabel('Loss')
axs[1, 0].set_xticks(rounds)  # Set x-axis ticks to whole numbers only
axs[1, 0].set_ylim(-0.1, 0.7)
axs[1, 0].legend()
axs[1, 0].grid(False)

# Plot Global Model Loss
axs[1, 1].plot(rounds, global_loss, marker='o', color='black', label='Global Loss', linestyle='-')
axs[1, 1].plot(rounds, global_val_loss, marker='x', color='black', label='Validation Loss', linestyle='--')
axs[1, 1].set_title('Global Model Loss Over Rounds')
axs[1, 1].set_xlabel('Rounds')
axs[1, 1].set_ylabel('Loss')
axs[1, 1].set_xticks(rounds)  # Set x-axis ticks to whole numbers only
axs[1, 1].set_ylim(-0.1, 0.7)
axs[1, 1].legend()
axs[1, 1].grid(False)

# Add a common title
fig.suptitle("Results Medical Non-IID Training", fontsize=16)

# Adjust layout to make room for the main title
plt.tight_layout(rect=[0, 0.03, 1, 0.95])

# Show the plots
plt.show()

# %%
from datetime import datetime

# Print the current date and time
print("This workbook was last run on:", datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
# Out:
# This workbook was last run on: 2024-09-03 14:17:51
